# %%
#Type and id

# %%
def square(num):
    return num**2

type(square)
# Out:
# function

# %%
type(square)
# Out:
# function

# %%
a=2
id(a)
# Out:
# 140721099600840

# %%
id(square)
# Out:
# 2746658214816

# %%
x=square
x
# Out:
# <function __main__.square(num)>

# %%
x
square(3)
# Out:
# 9

# %%
square(3)
# Out:
# 9

# %%
L=[1,2,3,4,square]
L
L[-1](3)
# Out:
# 9

# %%
s={square}
s
# Out:
# {<function __main__.square(num)>}

# %%
def f():
    def x(a,b):
        return a+b
    return x

val=f()(3,4)
val
# Out:
# 7

# %%
def func_a():
    print("inside func_a")
def func_b(z):
    print("inside func_c")
    return z()
print(func_b(func_a))
# Out:
# inside func_c
# inside func_a
# None

# %%
#x-> x^2
a=lambda x:x**2
a(2)
# Out:
# 4

# %%
a=lambda x,y:x+y
a(5,2)
# Out:
# 7

# %%
#check if a string has 'a'
a=lambda s:'a' in s
a('helloa')
# Out:
# True

# %%
#odd or even 
a=lambda x:'even' if x%2==0 else 'odd'
a(5)
# Out:
# 'odd'

# %%
# def square(x):
#     return x**2
# def cube(x):
#     return x**3
def transform(f,l):
    output=[]
    for i in L:
        output.append(f(i))
    print(output)
L=[1,2,3,4,5]

transform(lambda x:x**3,L)
# Out:
# [1, 8, 27, 64, 125]

# %%
list(map(lambda x:x**2,[1,2,3,4,5]))
# Out:
# [1, 4, 9, 16, 25]

# %%
L=[1,2,3,4,5]
list(map(lambda x:'even' if x%2==0 else 'odd',L))
# Out:
# ['odd', 'even', 'odd', 'even', 'odd']

# %%
users=[
    {
        'name':'Rahul',
        'age':45
    },
    {
        'name':'Nitish',
        'age':33
    },
    {
        'name':'Ankita',
        'age':50
    }
]
list(map(lambda users:users['name'],users))
# Out:
# ['Rahul', 'Nitish', 'Ankita']

# %%
#numbers greater than 5
L=[3,4,5,6,7,8]
list(filter(lambda x:x>5,L))
# Out:
# [6, 7, 8]

# %%
fruits=['apple','guava','cherry']
list(filter(lambda x:x.startswith('a'),fruits))
# Out:
# ['apple']

# %%
import functools
functools.reduce(lambda x,y:x+y,[1,2,3,4,5])

# %%
functools.reduce(lambda x,y:x if x<y else y,[23,11,45,1])
# Out:
# 1
