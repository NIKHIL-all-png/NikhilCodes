# %%
#Type and id

# %%
def square(num):
    return num**2

type(square)
# Out:
# function

# %%
type(square)
# Out:
# function

# %%
a=2
id(a)
# Out:
# 140721348309960

# %%
id(square)
# Out:
# 1875815424672

# %%
x=square
x
# Out:
# <function __main__.square(num)>
